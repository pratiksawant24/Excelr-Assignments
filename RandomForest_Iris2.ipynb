# %%
import pandas as pd
import numpy as np

# %%
iris = pd.read_csv("iris.csv")

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
iX=iris[["Sepal.Length","Sepal.Width","Petal.Length","Petal.Width"]]
iy=iris[["Species"]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfiris = RandomForestClassifier(n_jobs=4,oob_score=True,n_estimators=100,criterion="entropy")

# %%
rfiris.fit(iX,iy)
iris["rf_pred"] = rfiris.predict(iX)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(iris["Species"],iris["rf_pred"])
# Out:
# array([[50,  0,  0],
#        [ 0, 50,  0],
#        [ 0,  0, 50]], dtype=int64)

# %%
colnames = list(iris.columns)

# %%
predictors = colnames[:4]

# %%
target = colnames[4]

# %%
np.shape(iris)
# Out:
# (150, 6)

# %%
rfiris.fit(iX,iy)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=4,
#                        oob_score=True, random_state=None, verbose=0,
#                        warm_start=False)

# %%
rfiris.estimators_
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1128928158, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1082207260, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
# ...

# %%
rfiris.classes_ # class labels (output)
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
rfiris.n_classes_ # Number of levels in class labels
# Out:
# 3

# %%
rfiris.n_features_  # Number of input features in model 4 here.
# Out:
# 4

# %%
rfiris.n_outputs_ # Number of outputs when fit performed
# Out:
# 1

# %%
rfiris.oob_score_  # 0.9466
# Out:
# 0.9466666666666667

# %%
rfiris.predict(iX)
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %%
iris['rf_pred'] = rfiris.predict(iX)

# %%
cols = ['rf_pred','Species']

# %%
iris[cols].head()
# Out:
#   rf_pred Species
# 0  setosa  setosa
# 1  setosa  setosa
# 2  setosa  setosa
# 3  setosa  setosa
# 4  setosa  setosa

# %%
iris["Species"]
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: Species, Length: 150, dtype: object

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(iris['Species'],iris['rf_pred']) # Confusion matrix
# Out:
# array([[50,  0,  0],
#        [ 0, 50,  0],
#        [ 0,  0, 50]], dtype=int64)

# %%
pd.crosstab(iris['Species'],iris['rf_pred'])
# Out:
# rf_pred     setosa  versicolor  virginica
# Species
# setosa          50           0          0
# versicolor       0          50          0
# virginica        0           0         50
